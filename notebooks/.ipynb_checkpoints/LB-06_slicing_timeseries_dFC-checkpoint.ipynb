# %%
# %matplotlib inline

from nistats.design_matrix import make_design_matrix
import numpy as np # the Python array package
import matplotlib.pyplot as plt  # the Python plotting package
from nilearn.connectome import ConnectivityMeasure
from nilearn import plotting 

import pandas as pd
# Out:
# /home/finc/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
t_r = 2
n_scans = 340

onsets_dir = '/home/finc/Dropbox/Projects/LearningBrain/github/LearningBrain_networks/support/onsets_dualnback.csv'
events = pd.read_csv(onsets_dir)
frame_times = np.arange(n_scans) * t_r

#------ step 1
box = make_design_matrix(frame_times, events, hrf_model = None)
box = box.reset_index()

# ----- step 2

box_hrf = make_design_matrix(frame_times, events, hrf_model = 'glover')
box_hrf  = box_hrf.reset_index()
# Out:
# /home/finc/anaconda/lib/python3.6/site-packages/nistats/utils.py:182: UserWarning: Matrix is singular at working precision, regularizing...
#   warn('Matrix is singular at working precision, regularizing...')

# %%
events = events[(events.trial_type == '1-back') | (events.trial_type == '2-back')].reset_index()

# %%
events['trial_type'] = np.arange(20)

# %%
frame_times = np.arange(n_scans) * t_r

#------ step 1
box_hrf = make_design_matrix(frame_times, events, hrf_model = 'glover')
box_hrf  = box_hrf.reset_index()
plt.plot(box_hrf.iloc[:,5])

# %%
from sklearn.covariance import EmpiricalCovariance

top_dir = '/home/finc/Dropbox/Projects/LearningBrain/data/neuroimaging/'

data6 = np.load(top_dir + 'LearningBrain_dualnback_timeseries_acompcor_24par_008_25.npy')

data = data6

sub_n = len(data[:, 0, 0, 0])
ses_n = len(data[0, :, 0, 0])
cond = np.arange(0,20)
rois_n = len(data[0, 0, 0, :])


correlation_matrices_wei = np.zeros((sub_n, ses_n, len(cond), rois_n, rois_n))


for sub in range(sub_n):
    for ses in range(ses_n):                 
        correlation_measure = ConnectivityMeasure(cov_estimator=EmpiricalCovariance(store_precision=True, assume_centered=False), kind = 'correlation', discard_diagonal=True)
        
        for con in range(len(cond)):
            rect_box_hrf = np.array([0 if elem < 0 else elem for elem in box_hrf[cond[con]]])
            rect_nnz = rect_box_hrf[np.nonzero(rect_box_hrf)]
                        
            timeseries_dual = data[sub, ses, rect_box_hrf > 0, :]
            
            timeseries_dual = (timeseries_dual.T * rect_nnz).T
            
            fc = correlation_measure.fit_transform([timeseries_dual])[0]
            np.fill_diagonal(fc, 0)
                        
            correlation_matrices_wei[sub, ses, con, :, :] = np.arctanh(fc)
            
correlation_matrices_wei.shape
# Out:
# (46, 4, 20, 264, 264)

# %%
import scipy.io as sio

sio.savemat(top_dir + 'LearningBrain_dFC_matrices_dualnback_data6.mat', {'correlation_matrices_wei': correlation_matrices_wei})

# %%
box_hrf.columns[20]
# Out:
# 19

# %%
df.columns = df.columns.str.replace("[()]", "_")

# %%
box_hrf.columns[1:21].values = new_names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-4fe42572274e> in <module>()
# ----> 1 box_hrf.columns[1:21].values = new_names
#
# AttributeError: can't set attribute

# %%
onsets_1back = np.array([4, 72, 140, 208, 276, 344, 412, 480, 548, 616])
onsets_2back = np.array([38, 106, 174, 242, 310, 378, 446, 514, 582, 650])

onsets_nback = sorted(np.concatenate((onsets_1back, onsets_2back), axis = 0))
vol_num = 340

TR = 2
duration = 30

vectors_blocks = np.zeros((vol_num, len(onsets_nback)))

# %%
for i in range(len(onsets_nback)):
    vector = np.zeros(vol_num)
    start = int(onsets_nback[i]/TR)
    stop = start + int(duration/TR)
    vector[start:stop] = 1       
    vectors_blocks[:,i] = vector

# %%
#plt.plot(vectors_blocks)

plt.pcolormesh(vectors_blocks)
plt.show()

# %%
vectors_blocks = vectors_blocks.astype('bool')

# %%
top_dir = '/home/finc/Dropbox/Projects/LearningBrain/data/neuroimaging/'

# %%
timeseries = np.load(top_dir + 'LearningBrain_dualnback_timeseries_hp_0.009_aCompCor_power_conn_style.npy')

timeseries.shape
# Out:
# (46, 4, 340, 264)

# %%
n_sub = len(timeseries[:, 0, 0, 0 ])
n_ses = len(timeseries[0, :, 0, 0 ])
n_roi = len(timeseries[0, 0, 0, : ])
n_win = len(vectors_blocks[0,:])

correlation_matrices_dFC = np.zeros((n_sub, n_ses, n_win, n_roi, n_roi))


for i in range(n_sub):
    for j in range(n_ses):
        for k in range(n_win):
            window_timeseries = timeseries[i, j, vectors_blocks[:, k], :]
            correlation_measure = ConnectivityMeasure(kind = 'correlation')
            window_matrix = correlation_measure.fit_transform([window_timeseries])[0]
            np.fill_diagonal(window_matrix, 0)
            correlation_matrices_dFC[i, j, k, :, :] = window_matrix

# %%
correlation_matrices_dFC.shape
# Out:
# (46, 4, 20, 264, 264)

# %%
correlation_matrices_dFC.shape
# Out:
# (46, 4, 20, 264, 264)

# %%
plotting.plot_matrix(correlation_matrices_dFC[0, 0, 5, :, :])

# %%
plotting.plot_matrix(correlation_matrices_dFC[1, 0, 14, :, :])

# %%
np.save(top_dir + 'LearningBrain_dFC_matrices_dualnback.npy', correlation_matrices_dFC)

# %%
# Selecting subjects who finished the study

groups = pd.read_csv('/home/finc/Dropbox/Projects/LearningBrain/data/behavioral/group_assignment.csv')

trained = (groups.group == 'Experimental') | (groups.group == 'Control')
trained_subs = groups[trained]

#trained_subs.drop(['sub-23'], axis = 0)
#trained_subs[trained_subs.sub != 'sub-23']


#experimental = (trained_subs == 'Experimental')
#trained_subs = groups[trained]['sub']
#subs = pd.Series.tolist(trained_subs)
#subs.remove('sub-23')

#experimental['group'][22] == False

#experimental['group']

trained_subs

#trained_subs.index[22]

trained_subs = trained_subs[trained_subs['sub'] != 'sub-23']
experimental = (trained_subs == 'Experimental')

# %%
experimental
# Out:
# [False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True]

# %%
corr_dFC_experimental = correlation_matrices_dFC[experimental,:,:,:,:]

# %%
corr_dFC_experimental.shape
# Out:
# (22, 4, 20, 264, 264)

# %%
import scipy.io as sio

sio.savemat(top_dir + 'LearningBrain_dFC_matrices_dualnback_conn_style.mat', {'correlation_matrices_dFC': correlation_matrices_dFC})

# %%
sio.savemat(top_dir + 'corr_dFC_experimental.mat', {'corr_dFC_experimental': corr_dFC_experimental})

# %%
correlarion_matrices_dFC.shape
# Out:
# (3, 4, 20, 264, 264)
